# %%
from imageio import imread
import matplotlib.pyplot as plt
import numpy as np

# %%
I = imread('masoleh_gray.jpg')

# %%
I.dtype, I.shape
# Out:
# (dtype('uint8'), (353, 720))

# %%
plt.imshow(I,cmap='gray')
plt.show()

# %%
I_rev = I[::-1]
img = np.concatenate((I,I_rev), axis=0)

# %%
plt.figure(figsize=(14,7))
plt.imshow(img,cmap='gray')
plt.show()
